# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./datasets_hi4/datasets_hi4/train-data.csv", sep=";")
df.head()
# Out:
#      index  id_product  Region Country            Site  \
# 0   645874      156160  EUROPE      DE    NL_DC_Venray
# 1   469488      224631   CHINA      CN  CN_DC_Shanghai
# 2   348904      104047  EUROPE      GB       NL_DC_HLD
# 3  1725822       11823    EAJP      AU     AU_DC_Perth
# 4   404781      159924  EUROPE      ES       NL_DC_HLD
#
#                  Operations            Zone         Cluster  Reference proxy  \
# 0         Europe Operations            DACH         Germany  reference-13523
# 1          China Operations      China & HK           China  reference-12778
# 2         Europe Operations  UK and Ireland  United Kingdom   reference-3513
# 3  International Operations         Pacific       Australia    reference-672
# 4         Europe Operations          Iberia           Spain   reference-3496
#
#   Product  Line proxy Division proxy    Customer Persona proxy  \
# 0      Product Line-4     Division-3   Customer Segmentation-3
# ...

# %%
# convert last column to int (remove the " " and convert str to int)
for column in ["Month 1", "Month 2", "Month 3", "Month 4"]:
    print("Nan values in column {}: {}".format(column, df[column].isna().sum()))
    df[column] = df[column].str.replace(" ", "").dropna().astype(int)
df.head()
# Out:
# Nan values in column Month 1: 352330
# Nan values in column Month 2: 0
# Nan values in column Month 3: 0
# Nan values in column Month 4: 0
#      index  id_product  Region Country            Site  \
# 0   645874      156160  EUROPE      DE    NL_DC_Venray
# 1   469488      224631   CHINA      CN  CN_DC_Shanghai
# 2   348904      104047  EUROPE      GB       NL_DC_HLD
# 3  1725822       11823    EAJP      AU     AU_DC_Perth
# 4   404781      159924  EUROPE      ES       NL_DC_HLD
#
#                  Operations            Zone         Cluster  Reference proxy  \
# 0         Europe Operations            DACH         Germany  reference-13523
# 1          China Operations      China & HK           China  reference-12778
# 2         Europe Operations  UK and Ireland  United Kingdom   reference-3513
# 3  International Operations         Pacific       Australia    reference-672
# 4         Europe Operations          Iberia           Spain   reference-3496
#
# ...

# %%
df.describe()
# Out:
#               index    id_product
# count  3.173346e+06  3.173346e+06
# mean   1.101597e+06  1.223989e+05
# std    6.362905e+05  7.068357e+04
# min    0.000000e+00  0.000000e+00
# 25%    5.506670e+05  6.115800e+04
# 50%    1.101594e+06  1.223590e+05
# 75%    1.652761e+06  1.836168e+05
# max    2.203712e+06  2.448560e+05

# %%
# select categorical features from the dataset
category_features = df.select_dtypes(include=['object']).columns
x = df[category_features]
x.head()
# Out:
#    Region Country            Site                Operations            Zone  \
# 0  EUROPE      DE    NL_DC_Venray         Europe Operations            DACH
# 1   CHINA      CN  CN_DC_Shanghai          China Operations      China & HK
# 2  EUROPE      GB       NL_DC_HLD         Europe Operations  UK and Ireland
# 3    EAJP      AU     AU_DC_Perth  International Operations         Pacific
# 4  EUROPE      ES       NL_DC_HLD         Europe Operations          Iberia
#
#           Cluster  Reference proxy Product  Line proxy Division proxy  \
# 0         Germany  reference-13523      Product Line-4     Division-3
# 1           China  reference-12778      Product Line-4     Division-3
# 2  United Kingdom   reference-3513      Product Line-3     Division-2
# 3       Australia    reference-672      Product Line-1     Division-1
# 4           Spain   reference-3496      Product Line-3     Division-2
#
#      Customer Persona proxy Strategic Product Family proxy  \
# ...

# %%
y = df["Month 4"]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Month 4, dtype: int32

# %%
# plot the relationship between categorical features and the target
for column in category_features:
    plt.figure(figsize=(20, 10))
    sns.barplot(x=df[column], y=df["Month 4"])
    # set xticks at 90 degrees
    plt.xticks(rotation=90)
    plt.show()
